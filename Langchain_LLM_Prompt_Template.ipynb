# %%
# pip install langchain-google-genai python-dotenv
# Out:
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-4.3.7-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dotenv in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (1.2.3)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<3.0.0,>=1.65.0 (from langchain-google-genai)
#   Downloading google_genai-2.21.0-py3-none-any.whl.metadata (56 kB)
# Collecting langchain-core<2.0.0,>=1.6.1 (from langchain-google-genai)
#   Downloading langchain_core-1.6.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-google-genai) (2.13.5)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.14.2)
# Collecting google-auth<3.0.0,>=2.56.0 (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Downloading google_auth-2.57.0-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Collecting websockets<17.0,>=13.0.0 (from google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Downloading websockets-16.1.1-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.19)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Downloading cryptography-50.0.1-cp311-abi3-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.33)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai)
#   Downloading langchain_protocol-0.0.19-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.4.4)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (6.0.3)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai)
#   Downloading uuid_utils-0.17.0-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.12.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.1.1)
# Requirement already satisfied: pycparser in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.0)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Downloading pyasn1-0.6.4-py3-none-any.whl.metadata (8.4 kB)
# Downloading langchain_google_genai-4.3.7-py3-none-any.whl (79 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-2.21.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 2.9 MB/s  0:00:00
# Downloading google_auth-2.57.0-py3-none-any.whl (259 kB)
# Downloading langchain_core-1.6.1-py3-none-any.whl (571 kB)
#    ---------------------------------------- 0.0/571.5 kB ? eta -:--:--
#    ------------------ --------------------- 262.1/571.5 kB ? eta -:--:--
#    ---------------------------------------- 571.5/571.5 kB 1.8 MB/s  0:00:00
# Downloading uuid_utils-0.17.0-cp311-cp311-win_amd64.whl (177 kB)
# Downloading websockets-16.1.1-cp311-cp311-win_amd64.whl (180 kB)
# Downloading cryptography-50.0.1-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 5.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/3.8 MB 2.1 MB/s eta 0:00:02
#    ------------- -------------------------- 1.3/3.8 MB 2.0 MB/s eta 0:00:02
#    ------------------- -------------------- 1.8/3.8 MB 2.1 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.8 MB 2.1 MB/s eta 0:00:01
#    ------------------------------ --------- 2.9/3.8 MB 2.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 2.2 MB/s  0:00:01
# Downloading langchain_protocol-0.0.19-py3-none-any.whl (7.3 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyasn1-0.6.4-py3-none-any.whl (84 kB)
# Installing collected packages: filetype, websockets, uuid-utils, pyasn1, langchain-protocol, pyasn1-modules, cryptography, google-auth, langchain-core, google-genai, langchain-google-genai
#
#    ----------------------------------------  0/11 [filetype]
#    --- ------------------------------------  1/11 [websockets]
#    --- ------------------------------------  1/11 [websockets]
#    --- ------------------------------------  1/11 [websockets]
#    --- ------------------------------------  1/11 [websockets]
#    --- ------------------------------------  1/11 [websockets]
#    ------- --------------------------------  2/11 [uuid-utils]
#    ---------- -----------------------------  3/11 [pyasn1]
#    ---------- -----------------------------  3/11 [pyasn1]
#    ---------- -----------------------------  3/11 [pyasn1]
#    ---------- -----------------------------  3/11 [pyasn1]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    ------------------ ---------------------  5/11 [pyasn1-modules]
#    --------------------- ------------------  6/11 [cryptography]
#    --------------------- ------------------  6/11 [cryptography]
#    --------------------- ------------------  6/11 [cryptography]
#    --------------------- ------------------  6/11 [cryptography]
#    --------------------- ------------------  6/11 [cryptography]
#    --------------------- ------------------  6/11 [cryptography]
#    --------------------- ------------------  6/11 [cryptography]
#    --------------------- ------------------  6/11 [cryptography]
#    --------------------- ------------------  6/11 [cryptography]
#    --------------------- ------------------  6/11 [cryptography]
#    --------------------- ------------------  6/11 [cryptography]
#    ------------------------- --------------  7/11 [google-auth]
#    ------------------------- --------------  7/11 [google-auth]
#    ------------------------- --------------  7/11 [google-auth]
#    ------------------------- --------------  7/11 [google-auth]
#    ------------------------- --------------  7/11 [google-auth]
#    ------------------------- --------------  7/11 [google-auth]
#    ------------------------- --------------  7/11 [google-auth]
#    ------------------------- --------------  7/11 [google-auth]
#   Attempting uninstall: langchain-core
#    ------------------------- --------------  7/11 [google-auth]
#     Found existing installation: langchain-core 0.3.74
#    ------------------------- --------------  7/11 [google-auth]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#     Uninstalling langchain-core-0.3.74:
#    ----------------------------- ----------  8/11 [langchain-core]
#       Successfully uninstalled langchain-core-0.3.74
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    ----------------------------- ----------  8/11 [langchain-core]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    -------------------------------- -------  9/11 [google-genai]
#    ------------------------------------ --- 10/11 [langchain-google-genai]
#    ------------------------------------ --- 10/11 [langchain-google-genai]
#    ---------------------------------------- 11/11 [langchain-google-genai]
#
# Successfully installed cryptography-50.0.1 filetype-1.2.0 google-auth-2.57.0 google-genai-2.21.0 langchain-core-1.6.1 langchain-google-genai-4.3.7 langchain-protocol-0.0.19 pyasn1-0.6.4 pyasn1-modules-0.4.2 uuid-utils-0.17.0 websockets-16.1.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.6.1 which is incompatible.
# langchain-community 0.3.26 requires langchain-core<1.0.0,>=0.3.66, but you have langchain-core 1.6.1 which is incompatible.
# langchain-openai 0.3.29 requires langchain-core<1.0.0,>=0.3.74, but you have langchain-core 1.6.1 which is incompatible.
# langchain-text-splitters 0.3.9 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.6.1 which is incompatible.

# %%
GOOGLE_API_KEY="AQ.Ab8RN6LYt0gwlLxs0x2Ka8XhtZAXdAoNYSZXvLRtcGjKerIr1A"

# %%
import os
from dotenv import load_dotenv

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# 🔐 Load API key from .env
load_dotenv()

google_api_key = os.getenv("GOOGLE_API_KEY")

# 🔸 Initialize Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    google_api_key=google_api_key
)

# 🔸 Create Prompt Template
prompt = PromptTemplate.from_template(
    "Answer clearly: {question}"
)

# 🔸 Create LLMChain
qa_chain = LLMChain(
    llm=llm,
    prompt=prompt
)

# 🚀 Run a query
query = "What is LangGraph in LangChain?"

response = qa_chain.run({
    "question": query
})

# 🖨️ Output
print("\nUser Question:", query)
print("\nLLM Answer:", response)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 import os
#       2 from dotenv import load_dotenv
#       3
# ----> 4 from langchain_google_genai import ChatGoogleGenerativeAI
#       5 from langchain.prompts import PromptTemplate
#       6 from langchain.chains import LLMChain
#       7
#
# File ~\anaconda3\envs\langchain\Lib\site-packages\langchain_google_genai\__init__.py:48
#      39 from langchain_google_genai._enums import (
#      40     ComputerUse,
#      41     Environment,
#    (...)     45     Modality,
#      46 )
#      47 from langchain_google_genai._version import __version__
# ---> 48 from langchain_google_genai.chat_models import ChatGoogleGenerativeAI
#      49 from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings
#      50 from langchain_google_genai.llms import GoogleGenerativeAI
#
# File ~\anaconda3\envs\langchain\Lib\site-packages\langchain_google_genai\chat_models.py:67
#      62 from google.genai.types import Tool as GoogleTool
#      63 from langchain_core.callbacks.manager import (
#      64     AsyncCallbackManagerForLLMRun,
#      65     CallbackManagerForLLMRun,
#      66 )
# ---> 67 from langchain_core.exceptions import (
#      68     ContextOverflowError,
#      69     ModelAPIError,
#      70     ModelAuthenticationError,
#      71     ModelInvalidRequestError,
#      72     ModelNotFoundError,
#      73     ModelPermissionDeniedError,
#      74     ModelRateLimitError,
#      75 )
#      76 from langchain_core.language_models import (
#      77     LangSmithParams,
#      78     LanguageModelInput,
#    (...)     81     is_openai_data_block,
#      82 )
#      83 from langchain_core.language_models.chat_models import BaseChatModel
#
# ImportError: cannot import name 'ContextOverflowError' from 'langchain_core.exceptions' (C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages\langchain_core\exceptions.py)

# %%
import os
from dotenv import load_dotenv

from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0,
    google_api_key=os.getenv("GOOGLE_API_KEY")
)

response = llm.invoke("What is LangGraph in LangChain?")

print(response.content)

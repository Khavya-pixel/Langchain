# %%
# pip install -U langchain langchain-google-genai python-dotenv
# Out:
# Requirement already satisfied: langchain in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (1.4.0)
# Requirement already satisfied: langchain-google-genai in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (4.4.0)
# Requirement already satisfied: python-dotenv in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (1.2.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain) (1.6.2)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain) (2.13.5)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.4.4)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.14.2)
# Requirement already satisfied: certifi in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.4)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: requests<3,>=2 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.34.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from requests<3,>=2->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.7.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=2.20.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from langchain-google-genai) (2.21.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.57.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (50.0.1)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.1.1)
# Requirement already satisfied: pycparser in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\khavy\anaconda3\envs\langchain\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.6.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

# Gemini / Google LangChain
from langchain_google_genai import ChatGoogleGenerativeAI

# LangChain components
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from langchain.agents import Tool


# 🔐 Load API key from .env
load_dotenv(dotenv_path=".env")

google_api_key = os.getenv("GOOGLE_API_KEY")

# Check whether API key is loaded
print("API key loaded:", bool(google_api_key))
print("API key length:", len(google_api_key) if google_api_key else 0)


# 🔸 Initialize Gemini LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key=google_api_key,
    temperature=0
)


# ============================================================
# ✅ Tool 1: Simple QA Tool
# ============================================================

qa_prompt = PromptTemplate.from_template(
    "Answer clearly and accurately:\n\n{question}"
)

qa_chain = LLMChain(
    llm=llm,
    prompt=qa_prompt
)

qa_tool = Tool(
    name="Simple QA",
    func=qa_chain.run,
    description="Answer factual questions clearly"
)


# ============================================================
# ✅ Tool 2: Summarizer Tool
# ============================================================

summary_prompt = PromptTemplate.from_template(
    "Summarize the following text clearly and concisely:\n\n{text}"
)

summary_chain = LLMChain(
    llm=llm,
    prompt=summary_prompt
)

summary_tool = Tool(
    name="Summarizer",
    func=summary_chain.run,
    description="Summarizes input text"
)


# ============================================================
# 🔧 Tool usage examples
# ============================================================

qa_query = "What is LangGraph in LangChain?"

summary_text = """
LangGraph is a library built on top of LangChain that helps developers
create stateful, multi-step agents as graphs. Each node represents a step
like calling an LLM or a tool. It's ideal for advanced AI workflows.
"""


# ============================================================
# 🚀 Run tools manually
# ============================================================

print("\n🧠 Simple QA Tool Output:\n")

print(
    qa_tool.run({
        "question": qa_query
    })
)


print("\n📝 Summarizer Tool Output:\n")

print(
    summary_tool.run({
        "text": summary_text
    })
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 8
#       4 # Gemini / Google LangChain
#       5 from langchain_google_genai import ChatGoogleGenerativeAI
#       6
#       7 # LangChain components
# ----> 8 from langchain.prompts import PromptTemplate
#       9 from langchain.chains import LLMChain
#      10 from langchain.agents import Tool
#      11
#
# ModuleNotFoundError: No module named 'langchain.prompts'
